# %% [markdown]
# # DQDW Task 3: Tidy up your Data

# %%
import pandas as pd
import numpy as np
import os
import uuid
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploring the Dataset

# %%
# read single tables
directory = "data/"
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

for f in files:    
    df = pd.read_csv(directory+f)
    print("\n", f.rsplit('.', 1)[0].replace("-", " ").capitalize())
    # look for empty rows
    print("Has empty rows?")
    print(df.isna().all(axis=1).any())
    # look for duplicates
    print("Has duplicated rows?")
    print(df.duplicated().any())
    #print(df.info())
    # look at the structure of the df
    #print(df.head(5))  ## comment out for performance if script is rerun
    # skimm for noise, i.e. items names that aren't real items
    #print(list(df['name_enus'].unique()))  ## comment out for performance if script is rerun
    # look at items without slot
    print(df['name_enus'][df['slotbak'].isna()].unique())  ## comment out for performance if script is rerun
# Out:
#  Back
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Formula: Enchant Cloak - Binding of Intellect'
#  'Formula: Enchant Cloak - Binding of Agility'
#  'Formula: Enchant Cloak - Binding of Strength'
#  'Formula: Enchant Cloak - Word of Intellect'
#  'Formula: Enchant Cloak - Word of Strength'
#  'Formula: Enchant Cloak - Word of Agility' nan]
#
#  Chest
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Medium Armor Kit' 'Heavy Armor Kit' 'Thick Armor Kit' 'Rugged Armor Kit'
#  'Knothide Armor Kit' 'Core Armor Kit' 'Heavy Knothide Armor Kit'
#  'Greater Rune of Warding' 'Lesser Rune of Warding'
#  "Vindicator's Armor Kit" "Magister's Armor Kit" 'Heavy Borean Armor Kit'
#  'Borean Armor Kit' 'Savage Armor Kit' 'Sha Armor Kit' nan]
#
#  Feet
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Medium Armor Kit' 'Heavy Armor Kit' 'Thick Armor Kit' 'Rugged Armor Kit'
#  'Knothide Armor Kit' 'Core Armor Kit' 'Heavy Knothide Armor Kit'
#  "Vindicator's Armor Kit" "Magister's Armor Kit" 'Heavy Borean Armor Kit'
#  'Borean Armor Kit' 'Savage Armor Kit' 'Sha Armor Kit' nan]
#
#  Finger
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Formula: Enchant Ring - Seal of Haste'
#  'Formula: Enchant Ring - Seal of Critical Strike'
#  'Formula: Enchant Ring - Accord of Critical Strike'
#  'Formula: Enchant Ring - Seal of Mastery'
#  'Formula: Enchant Ring - Seal of Versatility'
#  'Formula: Enchant Ring - Accord of Versatility'
#  'Formula: Enchant Ring - Accord of Haste'
#  'Formula: Enchant Ring - Pact of Critical Strike'
#  'Formula: Enchant Ring - Word of Versatility'
#  'Formula: Enchant Ring - Binding of Versatility'
#  'Formula: Enchant Ring - Binding of Haste'
#  'Formula: Enchant Ring - Binding of Mastery'
#  'Formula: Enchant Ring - Binding of Critical Strike'
#  'Formula: Enchant Ring - Pact of Haste'
#  'Formula: Enchant Ring - Accord of Mastery'
#  'Formula: Enchant Ring - Word of Critical Strike'
#  'Formula: Enchant Ring - Word of Mastery'
#  'Formula: Enchant Ring - Pact of Mastery'
#  'Formula: Enchant Ring - Pact of Versatility'
#  'Formula: Enchant Ring - Word of Haste'
#  'Formula: Accord of Critical Strike' 'Formula: Accord of Mastery'
#  'Formula: Accord of Haste' 'Formula: Accord of Versatility' nan]
#
#  Hands
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Medium Armor Kit' 'Heavy Armor Kit' 'Thick Armor Kit' 'Rugged Armor Kit'
#  'Knothide Armor Kit' 'Core Armor Kit' 'Glove Reinforcements'
#  'Heavy Knothide Armor Kit' "Vindicator's Armor Kit"
#  "Magister's Armor Kit" 'Heavy Borean Armor Kit' 'Borean Armor Kit'
#  'Savage Armor Kit' 'Sha Armor Kit'
#  'Formula: Enchant Gloves - Legion Herbalism'
#  'Formula: Enchant Gloves - Legion Skinning'
#  'Formula: Enchant Gloves - Legion Surveying'
#  'Formula: Enchant Gloves - Legion Mining' nan]
#
#  Head
# Has empty rows?
# True
# Has duplicated rows?
# True
# [nan]
#
#  Held in off hand
# Has empty rows?
# True
# Has duplicated rows?
# True
# [nan]
#
#  Legs
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Medium Armor Kit' 'Heavy Armor Kit' 'Thick Armor Kit' 'Rugged Armor Kit'
#  'Arcanum of Focus' 'Cobrahide Leg Armor' 'Clefthide Leg Armor'
#  'Lesser Arcanum of Voracity' 'Mystic Spellthread'
#  'Lesser Arcanum of Constitution' 'Silver Spellthread'
#  'Arcanum of Rapidity' 'Knothide Armor Kit' 'Arcanum of Protection'
#  'Core Armor Kit' 'Lesser Arcanum of Rumination'
#  'Lesser Arcanum of Tenacity' 'Nethercleft Leg Armor' 'Golden Spellthread'
#  'Heavy Knothide Armor Kit' 'Nethercobra Leg Armor' 'Runic Spellthread'
#  'Presence of Might' 'Prophetic Aura' "Vindicator's Armor Kit"
#  'Shadow Guard' "Syncretist's Sigil" "Falcon's Call"
#  "Vodouisant's Vigilant Embrace" 'Presence of Sight' "Death's Embrace"
#  'Hoodoo Hex' 'Savage Guard' 'Ice Guard' "Animist's Caress"
#  "Magister's Armor Kit" 'Brilliant Spellthread' 'Sapphire Spellthread'
#  'Jormungar Leg Armor' 'Nerubian Leg Armor' 'Heavy Borean Armor Kit'
#  'Azure Spellthread' 'Borean Armor Kit' 'Shining Spellthread'
#  'Icescale Leg Armor' 'Frosthide Leg Armor' 'Earthen Leg Armor'
#  'Ghostly Spellthread' 'Twilight Leg Armor' 'Savage Armor Kit'
#  'Enchanted Spellthread' 'Scorched Leg Armor' 'Shadowleather Leg Armor'
#  'Angerhide Leg Armor' 'Greater Cerulean Spellthread'
#  'Dragonscale Leg Armor' 'Greater Pearlescent Spellthread'
#  'Powerful Ghostly Spellthread' 'Ironscale Leg Armor' 'Sha Armor Kit'
#  'Brutal Leg Armor' 'Charscale Leg Armor' 'Drakehide Leg Armor'
#  'Sha-Touched Leg Armor' 'Pearlescent Spellthread' 'Cerulean Spellthread'
#  'Powerful Enchanted Spellthread' 'Toughened Leg Armor' nan]
#
#  Main hand
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Coarse Sharpening Stone' 'Minor Wizard Oil' 'Coarse Weightstone'
#  'Formula: Enchant Weapon - Executioner' 'Heavy Sharpening Stone'
#  'Heavy Weightstone' 'Minor Mana Oil' 'Frost Oil' 'Shadow Oil'
#  'Solid Sharpening Stone' 'Lesser Wizard Oil' 'Solid Weightstone'
#  'Dense Sharpening Stone' 'Lesser Mana Oil' 'Wizard Oil'
#  'Dense Weightstone' 'Elemental Sharpening Stone' 'Brilliant Wizard Oil'
#  'Fel Weightstone' 'Adamantite Weapon Chain' 'Brilliant Mana Oil'
#  'Blessed Wizard Oil' 'Fel Sharpening Stone'
#  'Consecrated Sharpening Stone' 'Superior Wizard Oil' 'Superior Mana Oil'
#  'Adamantite Sharpening Stone' 'Adamantite Weightstone'
#  'Titanium Weapon Chain' 'Bloodboil Poison' 'Blessed Weapon Coating'
#  'Righteous Weapon Coating' 'Exceptional Mana Oil'
#  'Living Steel Weapon Chain' 'Pyrium Weapon Chain'
#  'Formula: Enchant Weapon - Torrent of Elements'
#  'Formula: Enchant Weapon - Coastal Surge'
#  'Formula: Enchant Weapon - Deadly Navigation'
#  'Formula: Enchant Weapon - Quick Navigation'
#  'Formula: Enchant Weapon - Siphoning'
#  'Formula: Enchant Weapon - Gale-Force Striking'
#  'Formula: Enchant Weapon - Versatile Navigation'
#  'Formula: Enchant Weapon - Masterful Navigation'
#  'Formula: Enchant Weapon - Stalwart Navigation' nan]
#
#  Neck
# Has empty rows?
# False
# Has duplicated rows?
# True
# ['Formula: Enchant Neck - Mark of the Hidden Satyr'
#  'Formula: Enchant Neck - Mark of the Trained Soldier'
#  'Formula: Enchant Neck - Mark of the Claw'
#  'Formula: Enchant Neck - Mark of the Versatile'
#  'Formula: Enchant Neck - Mark of the Quick'
#  'Formula: Enchant Neck - Mark of the Heavy Hide'
#  'Formula: Enchant Neck - Mark of the Master'
#  'Formula: Enchant Neck - Mark of the Deadly'
#  'Formula: Enchant Neck - Mark of the Ancient Priestess'
#  'Formula: Enchant Neck - Mark of the Distant Army']
#
#  Off hand
# Has empty rows?
# False
# Has duplicated rows?
# True
# ['Coarse Sharpening Stone' 'Minor Wizard Oil' 'Coarse Weightstone'
#  'Formula: Enchant Weapon - Executioner' 'Heavy Sharpening Stone'
#  'Heavy Weightstone' 'Minor Mana Oil' 'Frost Oil' 'Shadow Oil'
#  'Solid Sharpening Stone' 'Lesser Wizard Oil' 'Solid Weightstone'
#  'Dense Sharpening Stone' 'Lesser Mana Oil' 'Wizard Oil'
#  'Dense Weightstone' 'Elemental Sharpening Stone' 'Brilliant Wizard Oil'
#  'Fel Weightstone' 'Adamantite Weapon Chain' 'Brilliant Mana Oil'
#  'Blessed Wizard Oil' 'Fel Sharpening Stone'
#  'Consecrated Sharpening Stone' 'Superior Wizard Oil' 'Superior Mana Oil'
#  'Adamantite Sharpening Stone' 'Adamantite Weightstone'
#  'Titanium Weapon Chain' 'Bloodboil Poison' 'Blessed Weapon Coating'
#  'Righteous Weapon Coating' 'Exceptional Mana Oil'
#  'Living Steel Weapon Chain' 'Pyrium Weapon Chain'
#  'Formula: Enchant Weapon - Torrent of Elements'
#  'Formula: Enchant Weapon - Coastal Surge'
#  'Formula: Enchant Weapon - Deadly Navigation'
#  'Formula: Enchant Weapon - Quick Navigation'
#  'Formula: Enchant Weapon - Siphoning'
#  'Formula: Enchant Weapon - Gale-Force Striking'
#  'Formula: Enchant Weapon - Versatile Navigation'
#  'Formula: Enchant Weapon - Masterful Navigation'
#  'Formula: Enchant Weapon - Stalwart Navigation']
#
#  One hand
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Coarse Sharpening Stone' 'Minor Wizard Oil' 'Coarse Weightstone'
#  'Formula: Enchant Weapon - Executioner' 'Heavy Sharpening Stone'
#  'Heavy Weightstone' 'Minor Mana Oil' 'Frost Oil' 'Shadow Oil'
#  'Solid Sharpening Stone' 'Lesser Wizard Oil' 'Solid Weightstone'
#  'Dense Sharpening Stone' 'Lesser Mana Oil' 'Wizard Oil'
#  'Dense Weightstone' 'Elemental Sharpening Stone' 'Brilliant Wizard Oil'
#  'Fel Weightstone' 'Adamantite Weapon Chain' 'Brilliant Mana Oil'
#  'Blessed Wizard Oil' 'Fel Sharpening Stone'
#  'Consecrated Sharpening Stone' 'Superior Wizard Oil' 'Superior Mana Oil'
#  'Adamantite Sharpening Stone' 'Adamantite Weightstone'
#  'Titanium Weapon Chain' 'Bloodboil Poison' 'Blessed Weapon Coating'
#  'Righteous Weapon Coating' 'Exceptional Mana Oil'
#  'Living Steel Weapon Chain' 'Pyrium Weapon Chain'
#  'Formula: Enchant Weapon - Torrent of Elements'
#  'Formula: Enchant Weapon - Coastal Surge'
#  'Formula: Enchant Weapon - Deadly Navigation'
#  'Formula: Enchant Weapon - Quick Navigation'
#  'Formula: Enchant Weapon - Gale-Force Striking'
#  'Formula: Enchant Weapon - Siphoning'
#  'Formula: Enchant Weapon - Versatile Navigation'
#  'Formula: Enchant Weapon - Masterful Navigation'
#  'Formula: Enchant Weapon - Stalwart Navigation'
#  'Formula: Force Multiplier' 'Formula: Naga Hide'
#  "Formula: Machinist's Brilliance" 'Formula: Oceanic Restoration'
#  'REUSE ME [MTMM] (DNT)' nan]
#
#  Ranged
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Standard Scope' 'Minor Wizard Oil' 'Crude Scope' 'Accurate Scope'
#  'Minor Mana Oil' 'Deadly Scope' 'Lesser Wizard Oil' 'Lesser Mana Oil'
#  'Wizard Oil' 'Sniper Scope' 'Brilliant Wizard Oil'
#  'Biznicks 247x128 Accurascope' 'Adamantite Weapon Chain'
#  'Brilliant Mana Oil' 'Superior Wizard Oil' 'Superior Mana Oil'
#  'Stabilized Eternium Scope' 'Khorium Scope' 'Adamantite Scope'
#  'Titanium Weapon Chain' 'Heartseeker Scope' 'Diamond-Cut Refractor Scope'
#  'Sun Scope' "Flintlocke's Woodchucker" 'Gnomish X-Ray Scope'
#  'Safety Catch Removal Kit' 'R19 Threatfinder' 'Exceptional Mana Oil'
#  "Lord Blastington's Scope of Doom" 'Living Steel Weapon Chain'
#  'Pyrium Weapon Chain' 'Mirror Scope'
#  'Formula: Enchant Weapon - Torrent of Elements'
#  'Formula: Enchant Weapon - Coastal Surge'
#  'Formula: Enchant Weapon - Deadly Navigation'
#  'Formula: Enchant Weapon - Quick Navigation' 'Megawatt Filament'
#  'Formula: Enchant Weapon - Gale-Force Striking'
#  'Formula: Enchant Weapon - Siphoning' "Hemet's Heartseeker"
#  'Formula: Enchant Weapon - Versatile Navigation'
#  'Formula: Enchant Weapon - Masterful Navigation'
#  "Oglethorpe's Missile Splitter"
#  'Formula: Enchant Weapon - Stalwart Navigation' "Crow's Nest Scope"
#  'Incendiary Ammunition' 'Frost-Laced Ammunition'
#  'Monelite Scope of Alacrity' 'Formula: Force Multiplier'
#  'Formula: Naga Hide' "Formula: Machinist's Brilliance"
#  'Formula: Oceanic Restoration' 'REUSE ME [MTMM] (DNT)' nan]
#
#  Shield
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Titanium Plating' 'Titanium Shield Spike' 'Elementium Shield Spike'
#  'Ghost Iron Shield Spike' 'Pyrium Shield Spike' nan]
#
#  Shirt
# Has empty rows?
# False
# Has duplicated rows?
# False
# []
#
#  Shoulder
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Chromatic Mantle of the Dawn' 'Flame Mantle of the Dawn'
#  'Shadow Mantle of the Dawn' 'Arcane Mantle of the Dawn'
#  'Nature Mantle of the Dawn' 'Frost Mantle of the Dawn'
#  'Heavy Knothide Armor Kit' 'Might of the Scourge'
#  'Zandalar Signet of Might' 'Zandalar Signet of Mojo'
#  'Resilience of the Scourge' 'Fortitude of the Scourge'
#  'Zandalar Signet of Serenity' 'Power of the Scourge'
#  'Greater Inscription of the Gladiator' 'Greater Inscription of Warding'
#  'Greater Inscription of Faith' 'Greater Inscription of Vengeance'
#  'Greater Inscription of the Blade' 'Inscription of Warding'
#  'Greater Inscription of the Knight' 'Heavy Borean Armor Kit'
#  'Greater Inscription of the Orb' 'Greater Inscription of the Oracle'
#  'Borean Armor Kit' 'Greater Inscription of Discipline'
#  'Inscription of the Oracle' 'Inscription of the Blade'
#  'Inscription of Faith' 'Inscription of the Knight'
#  'Inscription of Endurance' 'Inscription of the Orb'
#  'Inscription of Discipline' 'Inscription of Vengeance'
#  'Lesser Inscription of the Axe' 'Lesser Inscription of the Crag'
#  'Lesser Inscription of the Pinnacle' 'Inscription of Triumph'
#  'Lesser Inscription of the Storm' 'Inscription of Dominance'
#  'Savage Armor Kit' 'Greater Tiger Claw Inscription'
#  'Greater Crane Wing Inscription' 'Greater Tiger Fang Inscription'
#  'Greater Inscription of Charged Lodestone' 'Greater Ox Horn Inscription'
#  'Greater Inscription of Jagged Stone'
#  'Greater Inscription of Shattered Crystal'
#  'Secret Crane Wing Inscription'
#  'Greater Inscription of Unbreakable Quartz'
#  'Lesser Inscription of Charged Lodestone'
#  'Lesser Inscription of Jagged Stone' 'Crane Wing Inscription'
#  'Tiger Fang Inscription' 'Sha Armor Kit'
#  'Lesser Inscription of Shattered Crystal'
#  'Lesser Inscription of Unbreakable Quartz'
#  'Secret Tiger Claw Inscription' 'Secret Tiger Fang Inscription'
#  'Greater Inscription of Vicious Strength' 'Tiger Claw Inscription'
#  'Greater Inscription of Vicious Intellect' 'Secret Ox Horn Inscription'
#  'Ox Horn Inscription' 'Greater Inscription of Vicious Agility' nan]
#
#  Tabard
# Has empty rows?
# True
# Has duplicated rows?
# True
# [nan]
#
#  Thrown
# Has empty rows?
# False
# Has duplicated rows?
# True
# []
#
#  Trinket
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Elemental Distillate' 'Wildswater' nan]
#
#  Two hand
# Has empty rows?
# True
# Has duplicated rows?
# True
# ['Nightcrawlers' 'Shiny Bauble' 'Coarse Sharpening Stone'
#  'Day-Old Darkmoon Doughnut' 'Minor Wizard Oil' 'Corpse Worm'
#  'Coarse Weightstone' 'Aquadynamic Fish Lens'
#  'Formula: Enchant Weapon - Executioner' 'Heavy Sharpening Stone'
#  'Heavy Weightstone' 'Minor Mana Oil' 'Frost Oil' 'Shadow Oil'
#  'Solid Sharpening Stone' 'Lesser Wizard Oil' 'Solid Weightstone'
#  'Dense Sharpening Stone' 'Lesser Mana Oil' 'Wizard Oil'
#  'Dense Weightstone' 'Elemental Sharpening Stone' 'Brilliant Wizard Oil'
#  'Fel Weightstone' 'Adamantite Weapon Chain' 'Brilliant Mana Oil'
#  'Blessed Wizard Oil' 'Fel Sharpening Stone'
#  'Consecrated Sharpening Stone' 'Superior Wizard Oil' 'Superior Mana Oil'
#  'Adamantite Sharpening Stone' 'Adamantite Weightstone'
#  'Titanium Weapon Chain' 'Bloodboil Poison' 'Blessed Weapon Coating'
#  'Righteous Weapon Coating' 'Exceptional Mana Oil'
#  'Living Steel Weapon Chain' 'Pyrium Weapon Chain'
#  'Formula: Enchant Weapon - Torrent of Elements'
#  'Formula: Enchant Weapon - Coastal Surge'
#  'Formula: Enchant Weapon - Deadly Navigation' "Rook's Lucky Fishin' Line"
#  'Formula: Enchant Weapon - Quick Navigation'
#  'Formula: Enchant Weapon - Siphoning'
#  'Formula: Enchant Weapon - Gale-Force Striking'
#  'Formula: Enchant Weapon - Versatile Navigation'
#  'Formula: Enchant Weapon - Masterful Navigation'
#  'Formula: Enchant Weapon - Stalwart Navigation' 'Ancient Fishing Line'
#  'Formula: Force Multiplier' 'Formula: Naga Hide'
#  "Formula: Machinist's Brilliance" 'Formula: Oceanic Restoration'
#  'REUSE ME [MTMM] (DNT)' nan]
#
#  Waist
# Has empty rows?
# True
# Has duplicated rows?
# True
# [nan]
#
#  Wrist
# Has empty rows?
# True
# Has duplicated rows?
# True
# [nan]

# %% [markdown]
# ## Reduce Noise & Join Tables

# %%
# get all file names in the directory
directory = "data/"
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# exclude thrown items from the data set since they are no longer equipable weapons
files.remove('thrown.csv')

data = pd.DataFrame()

for f in files:
    # get category from file name
    category = f.rsplit('.', 1)[0].replace("-", " ").capitalize()
    
    # read file
    df = pd.read_csv(directory+f)
    
    # delete empty rows and duplicates
    df.dropna(how='all', axis=0, inplace=True)
    df.drop_duplicates(inplace=True)
    
    # add category column
    df['category'] = category

    # append each df to the data df
    data = pd.concat([data, df], ignore_index=True)

# exclude consumable items and item enhancement items that do not have a slot assigned
data.drop(data[data['slotbak'].isna()].index, inplace=True)

# exculde items with generic item names that do not correspond to item names in game
data.drop(data[(data['name_enus'] == 'RING') | (data['name_enus'] == 'Ring')].index, inplace=True)
# excude placeholder items
data.drop(data[data['name_enus'].str.contains(' PH ')].index, inplace=True)
data.drop(data[data['name_enus'].str.contains(' Raid - ')].index, inplace=True)

data
# Out:
#          agi  agiint  agistr  agistrint  arcres  armor  atkpwr       classes  \
# 0      134.0     NaN     NaN      134.0     NaN   73.0     NaN           NaN
# 1      134.0     NaN     NaN      134.0     NaN   73.0     NaN           NaN
# 2      134.0     NaN     NaN      134.0     NaN   73.0     NaN           NaN
# 3        1.0     NaN     NaN        NaN     NaN    1.0     NaN           NaN
# 4        NaN     NaN     NaN        NaN     NaN    1.0     NaN           NaN
# ...      ...     ...     ...        ...     ...    ...     ...           ...
# 58213    NaN     NaN     NaN        NaN     NaN  309.0     NaN       Warrior
# 58214    NaN     NaN     NaN        NaN     NaN  309.0     NaN       Paladin
# 58215    NaN     NaN     NaN        NaN     NaN  309.0     NaN  Death knight
# 58216    NaN     NaN     NaN        NaN     NaN  309.0     NaN       Paladin
# 58217  194.0   194.0     NaN        NaN     NaN  141.0     NaN         Druid
#
#        cooldown  critstrkrtng  ...  rgdatkpwr  rgddmgmax  rgddmgmin  rgddps  \
# 0           NaN           NaN  ...        NaN        NaN        NaN     NaN
# 1           NaN          69.0  ...        NaN        NaN        NaN     NaN
# 2           NaN           NaN  ...        NaN        NaN        NaN     NaN
# 3           NaN           NaN  ...        NaN        NaN        NaN     NaN
# 4           NaN           NaN  ...        NaN        NaN        NaN     NaN
# ...         ...           ...  ...        ...        ...        ...     ...
# 58213       NaN          66.0  ...        NaN        NaN        NaN     NaN
# 58214       NaN          66.0  ...        NaN        NaN        NaN     NaN
# 58215       NaN          67.0  ...        NaN        NaN        NaN     NaN
# 58216       NaN          66.0  ...        NaN        NaN        NaN     NaN
# 58217       NaN          72.0  ...        NaN        NaN        NaN     NaN
#
#        rgdspeed  holres  avoidance resirtng  spi  splcritstrkrtng
# 0           NaN     NaN        NaN      NaN  NaN              NaN
# 1           NaN     NaN        NaN      NaN  NaN              NaN
# 2           NaN     NaN        NaN      NaN  NaN              NaN
# 3           NaN     NaN        NaN      NaN  NaN              NaN
# 4           NaN     NaN        NaN      NaN  NaN              NaN
# ...         ...     ...        ...      ...  ...              ...
# 58213       NaN     NaN        NaN      NaN  NaN              NaN
# 58214       NaN     NaN        NaN      NaN  NaN              NaN
# 58215       NaN     NaN        NaN      NaN  NaN              NaN
# 58216       NaN     NaN        NaN      NaN  NaN              NaN
# 58217       NaN     NaN        NaN      NaN  NaN              NaN
#
# [57689 rows x 66 columns]

# %%
print(data.shape)
data.info()
# Out:
# (57689, 66)
# <class 'pandas.core.frame.DataFrame'>
# Index: 57689 entries, 0 to 58217
# Data columns (total 66 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   agi              23676 non-null  float64
#  1   agiint           17217 non-null  float64
#  2   agistr           633 non-null    float64
#  3   agistrint        933 non-null    float64
#  4   arcres           56 non-null     float64
#  5   armor            41011 non-null  float64
#  6   atkpwr           1 non-null      float64
#  7   classes          14022 non-null  object
#  8   cooldown         1218 non-null   float64
#  9   critstrkrtng     25079 non-null  float64
#  10  dodgertng        1220 non-null   float64
#  11  firres           207 non-null    float64
#  12  frores           158 non-null    float64
#  13  hastertng        18661 non-null  float64
#  14  int              42226 non-null  float64
#  15  itemset          6067 non-null   float64
#  16  mastrtng         11909 non-null  float64
#  17  name_enus        57689 non-null  object
#  18  natres           97 non-null     float64
#  19  nsockets         10279 non-null  float64
#  20  parryrtng        684 non-null    float64
#  21  quality          57689 non-null  object
#  22  reqlevel         48870 non-null  float64
#  23  rgdhastepct      2 non-null      float64
#  24  slotbak          57689 non-null  float64
#  25  socket1          8797 non-null   object
#  26  socket2          5607 non-null   object
#  27  speed            8819 non-null   float64
#  28  splhastepct      2 non-null      float64
#  29  sta              50782 non-null  float64
#  30  str              15360 non-null  float64
#  31  strint           9316 non-null   float64
#  32  versatility      12419 non-null  float64
#  33  category         57689 non-null  object
#  34  dura             43039 non-null  float64
#  35  reqarenartng     182 non-null    float64
#  36  socket3          855 non-null    object
#  37  dmg              4 non-null      float64
#  38  healthrgn        20 non-null     float64
#  39  lifesteal        6 non-null      float64
#  40  rgdcritstrkrtng  3 non-null      float64
#  41  speedbonus       2 non-null      float64
#  42  armorbonus       2 non-null      float64
#  43  manargn          1 non-null      float64
#  44  reqspell         6 non-null      float64
#  45  splpwr           5 non-null      float64
#  46  sturdiness       1 non-null      float64
#  47  dmgmax1          8594 non-null   float64
#  48  dmgmin1          8594 non-null   float64
#  49  dps              8621 non-null   float64
#  50  mledmgmax        7079 non-null   float64
#  51  mledmgmin        7079 non-null   float64
#  52  mledps           7102 non-null   float64
#  53  mlespeed         7102 non-null   float64
#  54  pvppower         28 non-null     float64
#  55  corruption       6 non-null      float64
#  56  rgdatkpwr        2 non-null      float64
#  57  rgddmgmax        1030 non-null   float64
#  58  rgddmgmin        1030 non-null   float64
#  59  rgddps           1030 non-null   float64
#  60  rgdspeed         1030 non-null   float64
#  61  holres           0 non-null      float64
#  62  avoidance        2 non-null      float64
#  63  resirtng         3 non-null      float64
#  64  spi              1 non-null      float64
#  65  splcritstrkrtng  1 non-null      float64
# dtypes: float64(59), object(7)
# memory usage: 29.5+ MB

# %%
data.describe()
# Out:
#                 agi        agiint        agistr     agistrint     arcres  \
# count  23676.000000  17217.000000    633.000000    933.000000  56.000000
# mean      63.328434     53.450717    103.665087    399.879957  11.178571
# std      802.461271    568.254127   1991.678644   2745.815049   7.544070
# min        1.000000      1.000000      2.000000      3.000000   1.000000
# 25%       13.000000     14.000000      9.000000     23.000000   5.000000
# 50%       18.000000     18.000000     13.000000     26.000000   8.000000
# 75%       27.000000     30.000000     18.000000     69.000000  17.000000
# max    50116.000000  36316.000000  50116.000000  33084.000000  29.000000
#
#               armor  atkpwr     cooldown  critstrkrtng    dodgertng  ...  \
# count  41011.000000     1.0  1218.000000  25079.000000  1220.000000  ...
# mean      50.370852    11.0     0.108511     18.467802    12.131967  ...
# std      277.464379     NaN     0.758130     24.880518     4.484387  ...
# min        1.000000    11.0     0.000278      1.000000     3.000000  ...
# 25%       12.000000    11.0     0.016667      9.000000     9.000000  ...
# 50%       23.000000    11.0     0.033333     12.000000    11.000000  ...
# 75%       42.000000    11.0     0.033333     17.000000    15.000000  ...
# max    27386.000000    11.0    24.000000   1009.000000    32.000000  ...
#
#        rgdatkpwr    rgddmgmax    rgddmgmin       rgddps     rgdspeed  holres  \
# count   2.000000  1030.000000  1030.000000  1030.000000  1030.000000     0.0
# mean   26.500000    89.431068    62.240777    27.875000     2.991864     NaN
# std    14.849242   129.393271   103.528780    79.702472     0.150726     NaN
# min    16.000000     2.000000     1.000000     0.620000     0.060000     NaN
# 25%    21.250000    40.000000    26.000000    11.540000     3.000000     NaN
# 50%    26.500000    62.000000    38.000000    17.420000     3.000000     NaN
# 75%    31.750000    76.000000    49.000000    20.570000     3.000000     NaN
# max    37.000000  1024.000000   981.000000  2208.070000     3.000000     NaN
#
#        avoidance  resirtng   spi  splcritstrkrtng
# count   2.000000       3.0   1.0              1.0
# mean   22.500000       6.0  19.0             29.0
# std     4.949747       0.0   NaN              NaN
# min    19.000000       6.0  19.0             29.0
# 25%    20.750000       6.0  19.0             29.0
# 50%    22.500000       6.0  19.0             29.0
# 75%    24.250000       6.0  19.0             29.0
# max    26.000000       6.0  19.0             29.0
#
# [8 rows x 59 columns]

# %% [markdown]
# ## Alter Columns
# * Add *Slot* column based on the item category and remove *slotbak* column
# * Add *OnUseEffect* column based on *cooldown*
# * Add *SetItem* column to indicate whether an item hast a set bonus and remove *itemset* which contains inaccurate item set IDs
# * Add *ProfReq* column with the required profession and remove *reqspell* which is too specific
# * Add *ID* column as unique identifier
# * Remove *socketX* columns which contain incomplete data

# %% [markdown]
# ### Substitute *slotbak* by *Slot*
# Items fit into different item slots. Slotbak contains a wowhead specific item slot ID that doesn't correspond to the item slot ID in the game which could be used in macros. It is not transparent how wowhead determines the slot numbers, since they do not correspond to the slot IDs ingame. Thus, the column doesn't add valuable information.

# %%
data['category'].unique()
# Out:
# array(['Back', 'Chest', 'Feet', 'Finger', 'Hands', 'Head',
#        'Held in off hand', 'Legs', 'Main hand', 'Neck', 'Off hand',
#        'One hand', 'Ranged', 'Shield', 'Shirt', 'Shoulder', 'Tabard',
#        'Trinket', 'Two hand', 'Waist', 'Wrist'], dtype=object)

# %%
# define mapping from item category to in-game slot ID
category_slot = {
    'Head': 1,
    'Neck': 2,
    'Shoulder': 3,
    'Shirt': 4,
    'Chest': 5,
    'Waist': 6,
    'Legs': 7,
    'Feet': 8,
    'Wrist': 9,
    'Hands': 10,
    'Finger': 11,
    'Trinket': 13,
    'Back': 15,
    'Main hand': 16,
    'One hand': 16,
    'Ranged': 16,
    'Two hand': 16,
    'Held in off hand': 17,
    'Off hand': 17,
    'Shield': 17,
    'Tabard': 19
}

# Create a new column using map()
data['Slot'] = data['category'].map(category_slot)

data
# Out:
#          agi  agiint  agistr  agistrint  arcres  armor  atkpwr       classes  \
# 0      134.0     NaN     NaN      134.0     NaN   73.0     NaN           NaN
# 1      134.0     NaN     NaN      134.0     NaN   73.0     NaN           NaN
# 2      134.0     NaN     NaN      134.0     NaN   73.0     NaN           NaN
# 3        1.0     NaN     NaN        NaN     NaN    1.0     NaN           NaN
# 4        NaN     NaN     NaN        NaN     NaN    1.0     NaN           NaN
# ...      ...     ...     ...        ...     ...    ...     ...           ...
# 58213    NaN     NaN     NaN        NaN     NaN  309.0     NaN       Warrior
# 58214    NaN     NaN     NaN        NaN     NaN  309.0     NaN       Paladin
# 58215    NaN     NaN     NaN        NaN     NaN  309.0     NaN  Death knight
# 58216    NaN     NaN     NaN        NaN     NaN  309.0     NaN       Paladin
# 58217  194.0   194.0     NaN        NaN     NaN  141.0     NaN         Druid
#
#        cooldown  critstrkrtng  ...  rgddmgmax  rgddmgmin  rgddps  rgdspeed  \
# 0           NaN           NaN  ...        NaN        NaN     NaN       NaN
# 1           NaN          69.0  ...        NaN        NaN     NaN       NaN
# 2           NaN           NaN  ...        NaN        NaN     NaN       NaN
# 3           NaN           NaN  ...        NaN        NaN     NaN       NaN
# 4           NaN           NaN  ...        NaN        NaN     NaN       NaN
# ...         ...           ...  ...        ...        ...     ...       ...
# 58213       NaN          66.0  ...        NaN        NaN     NaN       NaN
# 58214       NaN          66.0  ...        NaN        NaN     NaN       NaN
# 58215       NaN          67.0  ...        NaN        NaN     NaN       NaN
# 58216       NaN          66.0  ...        NaN        NaN     NaN       NaN
# 58217       NaN          72.0  ...        NaN        NaN     NaN       NaN
#
#        holres  avoidance  resirtng spi  splcritstrkrtng  Slot
# 0         NaN        NaN       NaN NaN              NaN    15
# 1         NaN        NaN       NaN NaN              NaN    15
# 2         NaN        NaN       NaN NaN              NaN    15
# 3         NaN        NaN       NaN NaN              NaN    15
# 4         NaN        NaN       NaN NaN              NaN    15
# ...       ...        ...       ...  ..              ...   ...
# 58213     NaN        NaN       NaN NaN              NaN     9
# 58214     NaN        NaN       NaN NaN              NaN     9
# 58215     NaN        NaN       NaN NaN              NaN     9
# 58216     NaN        NaN       NaN NaN              NaN     9
# 58217     NaN        NaN       NaN NaN              NaN     9
#
# [57689 rows x 67 columns]

# %%
# delete the slot columns with wowhead slots
data.drop('slotbak', axis=1, inplace=True)
print(data.shape)
# Out:
# (57689, 66)

# %% [markdown]
# ### Add OnUseEffect Column
# Add the column *OnUseEffect* as boolean and set True if the column *cooldown* has a value.

# %%
data['OnUseEffect'] = data['cooldown'].notnull()
data[['name_enus', 'OnUseEffect', 'cooldown']][data['OnUseEffect'] == True]
# Out:
#                               name_enus  OnUseEffect  cooldown
# 283                       Wrap of Unity         True  4.000000
# 284               Cloak of Coordination         True  2.000000
# 286               Shroud of Cooperation         True  8.000000
# 462                       Cloak of Fire         True  0.033333
# 674                    Skywitch's Drape         True  0.500000
# ...                                 ...          ...       ...
# 50528                     Barbaric Belt         True  0.333333
# 50685         Nigh-Invulnerability Belt         True  0.083333
# 57923            Hyperthread Wristwraps         True  0.033333
# 57996               Anodized Deflectors         True  0.008333
# 58072  Wraps of Electrostatic Potential         True  0.016667
#
# [1218 rows x 3 columns]

# %% [markdown]
# ### Substitute *itemset* by *SetItem*
# The column *itemset* probably contains a wowhead set ID. This set ID indicates that items belong to a set and all items with the same set ID should form a set, but this is not always the case. The assignment of set IDs is inaccurate whereas the information on whether an item is a set item seems to be accurate. Thus, a *SetItem* column is created as type boolean to indicate whether an item is part of a set based on the set ID in *itemset* and the *itemset* column is removed.

# %%
data['SetItem'] = data['itemset'].notnull()
data[['name_enus', 'SetItem', 'itemset']][data['SetItem'] == True]
# Out:
#                           name_enus  SetItem  itemset
# 525        Drape of Vaulted Secrets     True    504.0
# 530          Cloak of Unending Life     True    494.0
# 539    Drape of Unyielding Strength     True    495.0
# 543         Cape of Eternal Justice     True    506.0
# 544        Cloak of the Unseen Path     True    510.0
# ...                             ...      ...      ...
# 30530         Deathlord's Legguards     True   1269.0
# 30533          Leggings of Azj'Aqir     True   1291.0
# 30540            Farseer's Leggings     True   1278.0
# 30553     Leggings of the Uncrowned     True   1277.0
# 30591   Leggings of the High Priest     True   1276.0
#
# [6067 rows x 3 columns]

# %%
data.drop('itemset', axis=1, inplace=True)
print(data.shape)
# Out:
# (57689, 67)

# %% [markdown]
# ### Substitute *reqspell* by *ProfReq*
# Add a column that contains the required profession for equipping and item. The columns is based on the column *reqspell* which contains the spell ID of the required profession receipt. This spell ID only applies to profession items and is a bit abstract and too specific, thus we will create a new columns containing the required profession or 'None' (as string). And later remove the columns *reqspell*.

# %%
 data[['name_enus', 'category', 'reqspell']][data['reqspell'].notnull()]  # all profession item in the data set are Enngineering items!
                                                                            # Other professions are missing...
# Out:
#                          name_enus category  reqspell
# 20708  Foreman's Reinforced Helmet     Head   20222.0
# 20717       Gnomish Battle Goggles     Head   20219.0
# 20745   Foreman's Enchanted Helmet     Head   20222.0
# 20773        Gnomish Power Goggles     Head   20219.0
# 44367       Goblin Rocket Launcher  Trinket   20222.0
# 44378          Gnomish Poultryizer  Trinket   20219.0

# %%
data['ProfReq'] = np.where(data['reqspell'].notnull(), 'Engineering', 'None')

print(data['ProfReq'].unique())

data[['name_enus', 'ProfReq', 'reqspell']][data['ProfReq'] != 'None']
# Out:
# ['None' 'Engineering']
#                          name_enus      ProfReq  reqspell
# 20708  Foreman's Reinforced Helmet  Engineering   20222.0
# 20717       Gnomish Battle Goggles  Engineering   20219.0
# 20745   Foreman's Enchanted Helmet  Engineering   20222.0
# 20773        Gnomish Power Goggles  Engineering   20219.0
# 44367       Goblin Rocket Launcher  Engineering   20222.0
# 44378          Gnomish Poultryizer  Engineering   20219.0

# %%
data.drop('reqspell', axis=1, inplace=True)
print(data.shape)
# Out:
# (57689, 67)

# %% [markdown]
# ### Remove socket Columns
# The nsocket columns gives information on the number of sockets an item has. The columns *socket1*, *socket2*, and *socket3* contain the type of socket, but there are socket types missing and the data is inconsistent. As shown below, in the data is only one socket type listed, whereas in the game several different socket types exist. It the following it is shown, that despite of *nsocket* giving a number of sockets, the corresponding values in socketX are missing if the socket type is any other than 'Prismatic Socket'. The data is incomplete and cannot be filled in reasonably. Thus the incomplete columns are removed.

# %%
data['socket3'].unique()  # there a socket types missing!
# Out:
# array([nan, 'Prismatic socket'], dtype=object)

# %%
empty_sockets = data[['name_enus', 'category', 'Slot',
                      'nsockets', 'socket1', 'socket2', 'socket3']][(data['nsockets'].isnull()) & (data['socket1'].notnull())]
empty_sockets  # same result for socket2 and socket3; nsockets seems to be correct
# Out:
# Empty DataFrame
# Columns: [name_enus, category, Slot, nsockets, socket1, socket2, socket3]
# Index: []

# %%
empty_sockets = data[['name_enus', 'category', 'Slot',
                      'nsockets', 'socket1', 'socket2', 'socket3']][(data['nsockets'] == 2) & (data['socket1'].isnull())]
empty_sockets  # values are also missing for all other combinations of nsockets and socket1/2/3 which should contain socket types!
# Out:
#                                 name_enus category  Slot  nsockets socket1  \
# 21011           Cursed Vision of Sargeras     Head     1       2.0     NaN
# 21013                     Voidheart Crown     Head     1       2.0     NaN
# 21016                    Deathmantle Helm     Head     1       2.0     NaN
# 21017                 Destroyer Greathelm     Head     1       2.0     NaN
# 21019                Netherblade Facemask     Head     1       2.0     NaN
# ...                                   ...      ...   ...       ...     ...
# 23331  Grievous Gladiator's Felweave Cowl     Head     1       2.0     NaN
# 23332     Helmet of the All-Consuming Maw     Head     1       2.0     NaN
# 23333  Grievous Gladiator's Ironskin Helm     Head     1       2.0     NaN
# 23334               Hood of Stilled Winds     Head     1       2.0     NaN
# 23335           Eternal Blossom Headguard     Head     1       2.0     NaN
#
#                 socket2 socket3
# 21011  Prismatic socket     NaN
# 21013  Prismatic socket     NaN
# 21016  Prismatic socket     NaN
# 21017  Prismatic socket     NaN
# 21019  Prismatic socket     NaN
# ...                 ...     ...
# 23331  Prismatic socket     NaN
# 23332  Prismatic socket     NaN
# 23333  Prismatic socket     NaN
# 23334  Prismatic socket     NaN
# 23335  Prismatic socket     NaN
#
# [1436 rows x 7 columns]

# %%
# delete socket columns since the data on socket type is incomplete and doesn't add value
data.drop(['socket1', 'socket2', 'socket3'], axis=1, inplace=True)
data.shape
# Out:
# (57689, 64)

# %% [markdown]
# ### Add ID Column
# Add a uuid for each item as unique identifier and primary key.

# %%
data.insert(0, 'ID', [uuid.uuid4() for _ in range(len(data))])
data
# Out:
#                                          ID    agi  agiint  agistr  agistrint  \
# 0      17469f65-d8f0-4ec6-859b-f9c0cda2a233  134.0     NaN     NaN      134.0
# 1      4134640b-4f39-4149-8fa8-126bd3848b1c  134.0     NaN     NaN      134.0
# 2      948166d8-0fed-41b4-8ed4-06a2b17f68bb  134.0     NaN     NaN      134.0
# 3      19efaf00-1328-42ea-ae7d-25822f83fc99    1.0     NaN     NaN        NaN
# 4      8d34a535-3873-4975-9581-2bc721e055b4    NaN     NaN     NaN        NaN
# ...                                     ...    ...     ...     ...        ...
# 58213  94e35998-2c99-4ac5-b238-ba631032ceab    NaN     NaN     NaN        NaN
# 58214  d0bc2a71-74c1-4a3f-b937-095180273b76    NaN     NaN     NaN        NaN
# 58215  dfb877d7-f8f2-4e66-ae8a-ceae55f979c5    NaN     NaN     NaN        NaN
# 58216  ab5a6976-1666-4128-acf0-a9cb58eac4ac    NaN     NaN     NaN        NaN
# 58217  d7cf0c96-ec53-4139-ac20-99587efcc330  194.0   194.0     NaN        NaN
#
#        arcres  armor  atkpwr       classes  cooldown  ...  rgdspeed  holres  \
# 0         NaN   73.0     NaN           NaN       NaN  ...       NaN     NaN
# 1         NaN   73.0     NaN           NaN       NaN  ...       NaN     NaN
# 2         NaN   73.0     NaN           NaN       NaN  ...       NaN     NaN
# 3         NaN    1.0     NaN           NaN       NaN  ...       NaN     NaN
# 4         NaN    1.0     NaN           NaN       NaN  ...       NaN     NaN
# ...       ...    ...     ...           ...       ...  ...       ...     ...
# 58213     NaN  309.0     NaN       Warrior       NaN  ...       NaN     NaN
# 58214     NaN  309.0     NaN       Paladin       NaN  ...       NaN     NaN
# 58215     NaN  309.0     NaN  Death knight       NaN  ...       NaN     NaN
# 58216     NaN  309.0     NaN       Paladin       NaN  ...       NaN     NaN
# 58217     NaN  141.0     NaN         Druid       NaN  ...       NaN     NaN
#
#        avoidance  resirtng  spi  splcritstrkrtng  Slot OnUseEffect  SetItem  \
# 0            NaN       NaN  NaN              NaN    15       False    False
# 1            NaN       NaN  NaN              NaN    15       False    False
# 2            NaN       NaN  NaN              NaN    15       False    False
# 3            NaN       NaN  NaN              NaN    15       False    False
# 4            NaN       NaN  NaN              NaN    15       False    False
# ...          ...       ...  ...              ...   ...         ...      ...
# 58213        NaN       NaN  NaN              NaN     9       False    False
# 58214        NaN       NaN  NaN              NaN     9       False    False
# 58215        NaN       NaN  NaN              NaN     9       False    False
# 58216        NaN       NaN  NaN              NaN     9       False    False
# 58217        NaN       NaN  NaN              NaN     9       False    False
#
#        ProfReq
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 58213     None
# 58214     None
# 58215     None
# 58216     None
# 58217     None
#
# [57689 rows x 65 columns]

# %% [markdown]
# ## Reorder & Rename Columns
# Reorder columns in a more meaningful way and choose informative column names.

# %%
cols = data.columns.to_list()
print(len(cols))
cols
# Out:
# 65
# ['ID',
#  'agi',
#  'agiint',
#  'agistr',
#  'agistrint',
#  'arcres',
#  'armor',
#  'atkpwr',
#  'classes',
#  'cooldown',
#  'critstrkrtng',
#  'dodgertng',
#  'firres',
#  'frores',
#  'hastertng',
#  'int',
#  'mastrtng',
#  'name_enus',
#  'natres',
#  'nsockets',
#  'parryrtng',
#  'quality',
#  'reqlevel',
#  'rgdhastepct',
#  'speed',
#  'splhastepct',
#  'sta',
#  'str',
#  'strint',
#  'versatility',
#  'category',
#  'dura',
#  'reqarenartng',
#  'dmg',
#  'healthrgn',
#  'lifesteal',
#  'rgdcritstrkrtng',
#  'speedbonus',
#  'armorbonus',
#  'manargn',
#  'splpwr',
#  'sturdiness',
#  'dmgmax1',
#  'dmgmin1',
#  'dps',
#  'mledmgmax',
#  'mledmgmin',
#  'mledps',
#  'mlespeed',
#  'pvppower',
#  'corruption',
#  'rgdatkpwr',
#  'rgddmgmax',
#  'rgddmgmin',
#  'rgddps',
#  'rgdspeed',
#  'holres',
#  'avoidance',
#  'resirtng',
#  'spi',
#  'splcritstrkrtng',
#  'Slot',
#  'OnUseEffect',
#  'SetItem',
#  'ProfReq']

# %% [markdown]
# ### Create Lists with column names

# %%
# define custom order of the columns
custom_order = ['ID', 'name_enus', 'category', 'Slot', 'quality', 'classes', 'reqlevel',
                'reqarenartng', 'ProfReq', 'OnUseEffect', 'nsockets', 'SetItem', 'agi', 'agiint',
                'agistr', 'agistrint', 'arcres', 'armor', 'atkpwr', 'avoidance', 'cooldown',
                'critstrkrtng', 'dodgertng', 'firres', 'frores', 'hastertng', 'int', 'mastrtng',
                'natres', 'parryrtng', 'rgdhastepct', 'speed', 'splhastepct', 'sta', 'str',
                'strint', 'versatility', 'dura', 'dmg', 'healthrgn', 'lifesteal',
                'rgdcritstrkrtng', 'speedbonus', 'armorbonus', 'manargn', 'splpwr',
                'sturdiness', 'dmgmax1', 'dmgmin1', 'dps', 'mledmgmax', 'mledmgmin', 'mledps',
                'mlespeed', 'pvppower', 'corruption', 'rgdatkpwr', 'rgddmgmax', 'rgddmgmin',
                'rgddps', 'rgdspeed', 'holres', 'resirtng', 'spi', 'splcritstrkrtng']

# define custom name for the columns
custom_col_names = ['ID', 'Name', 'Category', 'Slot', 'Quality', 'Class', 'LvlReq',
                    'ArenaRatingReq', 'ProfReq', 'OnUseEffect', 'Sockets', 'SetItem', 'Agility',
                    'AgilityIntellect', 'AgilityStrength', 'AgiStrInt', 'ArcaneResistance',
                    'Armor', 'AttackPower', 'Avoidance', 'Cooldown', 'CritStrikeRating',
                    'DodgeRating', 'FireResistance', 'FrostResistance', 'Haste', 'Intellect',
                    'Mastery', 'NatureResistance', 'ParryRating', 'RangedHastePercentage',
                    'Speed', 'SpellHastePercentage', 'Stamina', 'Strength', 'StrengthIntellect',
                    'Versatility', 'Durability', 'Damage', 'HealthReg', 'Lifesteal',
                    'RangedCritStrikeRating', 'SpeedBonus', 'ArmorBonus', 'ManaReg', 'SpellPower',
                    'Sturdiness', 'DamageMax', 'DamageMin', 'DPS', 'MeleeDamageMax', 'MeleeDamageMin',
                    'MeleeDPS', 'MeleeSpeed', 'PVPPower', 'Corruption', 'RangedAttackPower',
                    'RangedDamageMax', 'RangedDamageMin', 'RangedDPS', 'RangedSpeed',
                    'HolyResistance', 'PVPResilience', 'Spirit', 'SpellCritStrikeRating']
print(len(custom_order))
print(len(custom_col_names))
# Out:
# 65
# 65

# %%
data = data[custom_order]
data.columns = custom_col_names
data
# Out:
#                                          ID                           Name  \
# 0      17469f65-d8f0-4ec6-859b-f9c0cda2a233      Stormpike Soldier's Cloak
# 1      4134640b-4f39-4149-8fa8-126bd3848b1c         Stormpike Sage's Cloak
# 2      948166d8-0fed-41b4-8ed4-06a2b17f68bb  Frostwolf Legionnaire's Cloak
# 3      19efaf00-1328-42ea-ae7d-25822f83fc99                   Banner Cloak
# 4      8d34a535-3873-4975-9581-2bc721e055b4            Demon Scarred Cloak
# ...                                     ...                            ...
# 58213  94e35998-2c99-4ac5-b238-ba631032ceab            Oathsworn Armguards
# 58214  d0bc2a71-74c1-4a3f-b937-095180273b76              Sunsoul Armplates
# 58215  dfb877d7-f8f2-4e66-ae8a-ceae55f979c5         Heart-Lesion Armguards
# 58216  ab5a6976-1666-4128-acf0-a9cb58eac4ac              Sunsoul Armguards
# 58217  d7cf0c96-ec53-4139-ac20-99587efcc330            Springrain Bindings
#
#       Category  Slot   Quality         Class  LvlReq  ArenaRatingReq ProfReq  \
# 0         Back    15      Epic           NaN    10.0             NaN    None
# 1         Back    15      Epic           NaN    10.0             NaN    None
# 2         Back    15      Epic           NaN    10.0             NaN    None
# 3         Back    15  Uncommon           NaN     NaN             NaN    None
# 4         Back    15    Common           NaN     5.0             NaN    None
# ...        ...   ...       ...           ...     ...             ...     ...
# 58213    Wrist     9  Uncommon       Warrior   120.0             NaN    None
# 58214    Wrist     9  Uncommon       Paladin   120.0             NaN    None
# 58215    Wrist     9  Uncommon  Death knight   120.0             NaN    None
# 58216    Wrist     9  Uncommon       Paladin   120.0             NaN    None
# 58217    Wrist     9  Uncommon         Druid   120.0             NaN    None
#
#        OnUseEffect  ...  Corruption  RangedAttackPower  RangedDamageMax  \
# 0            False  ...         NaN                NaN              NaN
# 1            False  ...         NaN                NaN              NaN
# 2            False  ...         NaN                NaN              NaN
# 3            False  ...         NaN                NaN              NaN
# 4            False  ...         NaN                NaN              NaN
# ...            ...  ...         ...                ...              ...
# 58213        False  ...         NaN                NaN              NaN
# 58214        False  ...         NaN                NaN              NaN
# 58215        False  ...         NaN                NaN              NaN
# 58216        False  ...         NaN                NaN              NaN
# 58217        False  ...         NaN                NaN              NaN
#
#        RangedDamageMin  RangedDPS  RangedSpeed  HolyResistance  PVPResilience  \
# 0                  NaN        NaN          NaN             NaN            NaN
# 1                  NaN        NaN          NaN             NaN            NaN
# 2                  NaN        NaN          NaN             NaN            NaN
# 3                  NaN        NaN          NaN             NaN            NaN
# 4                  NaN        NaN          NaN             NaN            NaN
# ...                ...        ...          ...             ...            ...
# 58213              NaN        NaN          NaN             NaN            NaN
# 58214              NaN        NaN          NaN             NaN            NaN
# 58215              NaN        NaN          NaN             NaN            NaN
# 58216              NaN        NaN          NaN             NaN            NaN
# 58217              NaN        NaN          NaN             NaN            NaN
#
#        Spirit  SpellCritStrikeRating
# 0         NaN                    NaN
# 1         NaN                    NaN
# 2         NaN                    NaN
# 3         NaN                    NaN
# 4         NaN                    NaN
# ...       ...                    ...
# 58213     NaN                    NaN
# 58214     NaN                    NaN
# 58215     NaN                    NaN
# 58216     NaN                    NaN
# 58217     NaN                    NaN
#
# [57689 rows x 65 columns]

# %% [markdown]
# ## Fill in Missing Values & Change Data Types/ Units
# Convert columns that can only take on integer values to integers where values exist and round floating point numbers where values exist.
# * *LvlReq*, *ArenaRatingReq*, and *Sockets* are supposed to be integers.
# * *Class* is filled with 'all' as a placeholder
# * *cooldown* contains values of the cooldown duration for items with an on-use effect in hours, but most cooldowns have much shorter durations that can be better expressed in minutes and rounded to three decimal places

# %%
# convert columns to int type that can only contain whole numbers
data['LvlReq'] = data['LvlReq'].fillna(0).astype(int)
data['ArenaRatingReq'] = data['ArenaRatingReq'].fillna(0).astype(int)
data['Sockets'] = data['Sockets'].fillna(0).astype(int)

# fill column with default value that cannot be empty
data = data.fillna({'Class': 'all'})

# convert cooldown duration to minutes and round to 3 decimal places
data['Cooldown'] = (data['Cooldown'] * 60).round(3)

print(data.info())
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
data.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57689 entries, 0 to 58217
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      57689 non-null  object
#  1   Name                    57689 non-null  object
#  2   Category                57689 non-null  object
#  3   Slot                    57689 non-null  int64
#  4   Quality                 57689 non-null  object
#  5   Class                   57689 non-null  object
#  6   LvlReq                  57689 non-null  int32
#  7   ArenaRatingReq          57689 non-null  int32
#  8   ProfReq                 57689 non-null  object
#  9   OnUseEffect             57689 non-null  bool
#  10  Sockets                 57689 non-null  int32
#  11  SetItem                 57689 non-null  bool
#  12  Agility                 23676 non-null  float64
#  13  AgilityIntellect        17217 non-null  float64
#  14  AgilityStrength         633 non-null    float64
#  15  AgiStrInt               933 non-null    float64
#  16  ArcaneResistance        56 non-null     float64
#  17  Armor                   41011 non-null  float64
#  18  AttackPower             1 non-null      float64
#  19  Avoidance               2 non-null      float64
#  20  Cooldown                1218 non-null   float64
#  21  CritStrikeRating        25079 non-null  float64
#  22  DodgeRating             1220 non-null   float64
#  23  FireResistance          207 non-null    float64
#  24  FrostResistance         158 non-null    float64
#  25  Haste                   18661 non-null  float64
#  26  Intellect               42226 non-null  float64
#  27  Mastery                 11909 non-null  float64
#  28  NatureResistance        97 non-null     float64
#  29  ParryRating             684 non-null    float64
#  30  RangedHastePercentage   2 non-null      float64
#  31  Speed                   8819 non-null   float64
#  32  SpellHastePercentage    2 non-null      float64
#  33  Stamina                 50782 non-null  float64
#  34  Strength                15360 non-null  float64
#  35  StrengthIntellect       9316 non-null   float64
#  36  Versatility             12419 non-null  float64
#  37  Durability              43039 non-null  float64
#  38  Damage                  4 non-null      float64
#  39  HealthReg               20 non-null     float64
#  40  Lifesteal               6 non-null      float64
#  41  RangedCritStrikeRating  3 non-null      float64
#  42  SpeedBonus              2 non-null      float64
#  43  ArmorBonus              2 non-null      float64
#  44  ManaReg                 1 non-null      float64
#  45  SpellPower              5 non-null      float64
#  46  Sturdiness              1 non-null      float64
#  47  DamageMax               8594 non-null   float64
#  48  DamageMin               8594 non-null   float64
#  49  DPS                     8621 non-null   float64
#  50  MeleeDamageMax          7079 non-null   float64
#  51  MeleeDamageMin          7079 non-null   float64
#  52  MeleeDPS                7102 non-null   float64
#  53  MeleeSpeed              7102 non-null   float64
#  54  PVPPower                28 non-null     float64
#  55  Corruption              6 non-null      float64
#  56  RangedAttackPower       2 non-null      float64
#  57  RangedDamageMax         1030 non-null   float64
#  58  RangedDamageMin         1030 non-null   float64
#  59  RangedDPS               1030 non-null   float64
#  60  RangedSpeed             1030 non-null   float64
#  61  HolyResistance          0 non-null      float64
#  62  PVPResilience           3 non-null      float64
#  63  Spirit                  1 non-null      float64
#  64  SpellCritStrikeRating   1 non-null      float64
# dtypes: bool(2), float64(53), int32(3), int64(1), object(6)
# memory usage: 27.6+ MB
# None
#                                       ID                           Name  \
# 0   17469f65-d8f0-4ec6-859b-f9c0cda2a233      Stormpike Soldier's Cloak
# 1   4134640b-4f39-4149-8fa8-126bd3848b1c         Stormpike Sage's Cloak
# 2   948166d8-0fed-41b4-8ed4-06a2b17f68bb  Frostwolf Legionnaire's Cloak
# 3   19efaf00-1328-42ea-ae7d-25822f83fc99                   Banner Cloak
# 4   8d34a535-3873-4975-9581-2bc721e055b4            Demon Scarred Cloak
# 5   baf667e0-261d-429e-ab69-6e33291c96d1       Silver Embroidered Cloak
# 6   02d0e023-cbde-4d69-a81d-28303930202a          Imbued Infantry Cloak
# 7   5718f380-177e-4e86-b104-68d214c1c94e            Incorruptable Shawl
# 8   c966cff5-b9a8-49f1-802c-045c01246af0               Rathorian's Cape
# 9   c3d9e4df-e202-43e9-a158-b4c404b8b02a      Cloak of the Clarion Call
# 10  9982f5bb-3365-4149-93ba-de02f579e0bb         Embossed Leather Cloak
# 11  4c31e738-93f1-4438-991a-c92aed940371      Frostwolf Advisor's Cloak
# 12  2d7ab080-92bb-4cd1-b9db-21e0bc742b5f                    Willow Cape
# 13  021acd32-5d22-4177-abbf-3493c58bbdbb                    Gypsy Cloak
# 14  1482201f-a0e3-438a-b7ae-88f06fb0c069              Rain-Spotted Cape
# 15  071b757a-7b12-49e8-a976-42ef55d931b3     Handstitched Leather Cloak
# 16  7c5c8700-93cc-4abb-b5af-8ff75a3e6e2a                  Harvest Cloak
# 17  7bb0ec97-80ea-477e-be9e-588bf1b3b6f0                    Tidal Cloak
# 18  ad501a05-669b-4a20-abca-1cb2761cae9b      Scene Investigator's Wrap
# 19  018186d0-7e9a-4b54-abcc-0c48bf215953                  Mystic's Cape
#
#    Category  Slot   Quality Class  LvlReq  ArenaRatingReq ProfReq  \
# 0      Back    15      Epic   all      10               0    None
# 1      Back    15      Epic   all      10               0    None
# 2      Back    15      Epic   all      10               0    None
# 3      Back    15  Uncommon   all       0               0    None
# 4      Back    15    Common   all       5               0    None
# 5      Back    15      Rare   all       0               0    None
# 6      Back    15  Uncommon   all       4               0    None
# 7      Back    15  Uncommon   all       0               0    None
# 8      Back    15  Uncommon   all      10               0    None
# 9      Back    15      Rare   all       0               0    None
# 10     Back    15  Uncommon   all       8               0    None
# 11     Back    15      Epic   all      10               0    None
# 12     Back    15  Uncommon   all      10               0    None
# 13     Back    15    Common   all       6               0    None
# 14     Back    15  Uncommon   all       0               0    None
# 15     Back    15    Common   all       4               0    None
# 16     Back    15  Uncommon   all      10               0    None
# 17     Back    15  Uncommon   all       0               0    None
# 18     Back    15  Uncommon   all       0               0    None
# 19     Back    15  Uncommon   all      10               0    None
#
#     OnUseEffect  ...  Corruption  RangedAttackPower  RangedDamageMax  \
# 0         False  ...         NaN                NaN              NaN
# 1         False  ...         NaN                NaN              NaN
# 2         False  ...         NaN                NaN              NaN
# 3         False  ...         NaN                NaN              NaN
# 4         False  ...         NaN                NaN              NaN
# 5         False  ...         NaN                NaN              NaN
# 6         False  ...         NaN                NaN              NaN
# 7         False  ...         NaN                NaN              NaN
# 8         False  ...         NaN                NaN              NaN
# 9         False  ...         NaN                NaN              NaN
# 10        False  ...         NaN                NaN              NaN
# 11        False  ...         NaN                NaN              NaN
# 12        False  ...         NaN                NaN              NaN
# 13        False  ...         NaN                NaN              NaN
# 14        False  ...         NaN                NaN              NaN
# 15        False  ...         NaN                NaN              NaN
# 16        False  ...         NaN                NaN              NaN
# 17        False  ...         NaN                NaN              NaN
# 18        False  ...         NaN                NaN              NaN
# 19        False  ...         NaN                NaN              NaN
#
#     RangedDamageMin  RangedDPS  RangedSpeed  HolyResistance  PVPResilience  \
# 0               NaN        NaN          NaN             NaN            NaN
# 1               NaN        NaN          NaN             NaN            NaN
# 2               NaN        NaN          NaN             NaN            NaN
# 3               NaN        NaN          NaN             NaN            NaN
# 4               NaN        NaN          NaN             NaN            NaN
# 5               NaN        NaN          NaN             NaN            NaN
# 6               NaN        NaN          NaN             NaN            NaN
# 7               NaN        NaN          NaN             NaN            NaN
# 8               NaN        NaN          NaN             NaN            NaN
# 9               NaN        NaN          NaN             NaN            NaN
# 10              NaN        NaN          NaN             NaN            NaN
# 11              NaN        NaN          NaN             NaN            NaN
# 12              NaN        NaN          NaN             NaN            NaN
# 13              NaN        NaN          NaN             NaN            NaN
# 14              NaN        NaN          NaN             NaN            NaN
# 15              NaN        NaN          NaN             NaN            NaN
# 16              NaN        NaN          NaN             NaN            NaN
# 17              NaN        NaN          NaN             NaN            NaN
# 18              NaN        NaN          NaN             NaN            NaN
# 19              NaN        NaN          NaN             NaN            NaN
#
#     Spirit  SpellCritStrikeRating
# 0      NaN                    NaN
# 1      NaN                    NaN
# 2      NaN                    NaN
# 3      NaN                    NaN
# 4      NaN                    NaN
# 5      NaN                    NaN
# 6      NaN                    NaN
# 7      NaN                    NaN
# 8      NaN                    NaN
# 9      NaN                    NaN
# 10     NaN                    NaN
# 11     NaN                    NaN
# 12     NaN                    NaN
# 13     NaN                    NaN
# 14     NaN                    NaN
# 15     NaN                    NaN
# 16     NaN                    NaN
# 17     NaN                    NaN
# 18     NaN                    NaN
# 19     NaN                    NaN
#
# [20 rows x 65 columns]

# %%
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')

# %% [markdown]
# ## Split Table
# The table is splitted into 3 tables called *items*, *classes*, and *stats* to store them in a storage efficient normalized format in a DB.
# ### Create items Table

# %%
# create the items table containing general information on the item
item_cols = ['ID', 'Name', 'Category', 'Slot', 'Quality', 'LvlReq', 'ArenaRatingReq',
             'ProfReq', 'OnUseEffect', 'Sockets', 'SetItem']
items = data[item_cols]

print(items.info())
items
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57689 entries, 0 to 58217
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              57689 non-null  object
#  1   Name            57689 non-null  object
#  2   Category        57689 non-null  object
#  3   Slot            57689 non-null  int64
#  4   Quality         57689 non-null  object
#  5   LvlReq          57689 non-null  int32
#  6   ArenaRatingReq  57689 non-null  int32
#  7   ProfReq         57689 non-null  object
#  8   OnUseEffect     57689 non-null  bool
#  9   Sockets         57689 non-null  int32
#  10  SetItem         57689 non-null  bool
# dtypes: bool(2), int32(3), int64(1), object(5)
# memory usage: 3.9+ MB
# None
#                                          ID                           Name  \
# 0      17469f65-d8f0-4ec6-859b-f9c0cda2a233      Stormpike Soldier's Cloak
# 1      4134640b-4f39-4149-8fa8-126bd3848b1c         Stormpike Sage's Cloak
# 2      948166d8-0fed-41b4-8ed4-06a2b17f68bb  Frostwolf Legionnaire's Cloak
# 3      19efaf00-1328-42ea-ae7d-25822f83fc99                   Banner Cloak
# 4      8d34a535-3873-4975-9581-2bc721e055b4            Demon Scarred Cloak
# ...                                     ...                            ...
# 58213  94e35998-2c99-4ac5-b238-ba631032ceab            Oathsworn Armguards
# 58214  d0bc2a71-74c1-4a3f-b937-095180273b76              Sunsoul Armplates
# 58215  dfb877d7-f8f2-4e66-ae8a-ceae55f979c5         Heart-Lesion Armguards
# 58216  ab5a6976-1666-4128-acf0-a9cb58eac4ac              Sunsoul Armguards
# 58217  d7cf0c96-ec53-4139-ac20-99587efcc330            Springrain Bindings
#
#       Category  Slot   Quality  LvlReq  ArenaRatingReq ProfReq  OnUseEffect  \
# 0         Back    15      Epic      10               0    None        False
# 1         Back    15      Epic      10               0    None        False
# 2         Back    15      Epic      10               0    None        False
# 3         Back    15  Uncommon       0               0    None        False
# 4         Back    15    Common       5               0    None        False
# ...        ...   ...       ...     ...             ...     ...          ...
# 58213    Wrist     9  Uncommon     120               0    None        False
# 58214    Wrist     9  Uncommon     120               0    None        False
# 58215    Wrist     9  Uncommon     120               0    None        False
# 58216    Wrist     9  Uncommon     120               0    None        False
# 58217    Wrist     9  Uncommon     120               0    None        False
#
#        Sockets  SetItem
# 0            0    False
# 1            0    False
# 2            0    False
# 3            0    False
# 4            0    False
# ...        ...      ...
# 58213        0    False
# 58214        0    False
# 58215        0    False
# 58216        0    False
# 58217        0    False
#
# [57689 rows x 11 columns]

# %% [markdown]
# ### Create stats Table

# %%
no_stat_cols = ['Category', 'Slot', 'Quality', 'Class', 'LvlReq', 'ArenaRatingReq',
                'ProfReq', 'OnUseEffect', 'Sockets', 'SetItem']
stats = data.drop(columns=no_stat_cols)
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57689 entries, 0 to 58217
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      57689 non-null  object
#  1   Name                    57689 non-null  object
#  2   Agility                 23676 non-null  float64
#  3   AgilityIntellect        17217 non-null  float64
#  4   AgilityStrength         633 non-null    float64
#  5   AgiStrInt               933 non-null    float64
#  6   ArcaneResistance        56 non-null     float64
#  7   Armor                   41011 non-null  float64
#  8   AttackPower             1 non-null      float64
#  9   Avoidance               2 non-null      float64
#  10  Cooldown                1218 non-null   float64
#  11  CritStrikeRating        25079 non-null  float64
#  12  DodgeRating             1220 non-null   float64
#  13  FireResistance          207 non-null    float64
#  14  FrostResistance         158 non-null    float64
#  15  Haste                   18661 non-null  float64
#  16  Intellect               42226 non-null  float64
#  17  Mastery                 11909 non-null  float64
#  18  NatureResistance        97 non-null     float64
#  19  ParryRating             684 non-null    float64
#  20  RangedHastePercentage   2 non-null      float64
#  21  Speed                   8819 non-null   float64
#  22  SpellHastePercentage    2 non-null      float64
#  23  Stamina                 50782 non-null  float64
#  24  Strength                15360 non-null  float64
#  25  StrengthIntellect       9316 non-null   float64
#  26  Versatility             12419 non-null  float64
#  27  Durability              43039 non-null  float64
#  28  Damage                  4 non-null      float64
#  29  HealthReg               20 non-null     float64
#  30  Lifesteal               6 non-null      float64
#  31  RangedCritStrikeRating  3 non-null      float64
#  32  SpeedBonus              2 non-null      float64
#  33  ArmorBonus              2 non-null      float64
#  34  ManaReg                 1 non-null      float64
#  35  SpellPower              5 non-null      float64
#  36  Sturdiness              1 non-null      float64
#  37  DamageMax               8594 non-null   float64
#  38  DamageMin               8594 non-null   float64
#  39  DPS                     8621 non-null   float64
#  40  MeleeDamageMax          7079 non-null   float64
#  41  MeleeDamageMin          7079 non-null   float64
#  42  MeleeDPS                7102 non-null   float64
#  43  MeleeSpeed              7102 non-null   float64
#  44  PVPPower                28 non-null     float64
#  45  Corruption              6 non-null      float64
#  46  RangedAttackPower       2 non-null      float64
#  47  RangedDamageMax         1030 non-null   float64
#  48  RangedDamageMin         1030 non-null   float64
#  49  RangedDPS               1030 non-null   float64
#  50  RangedSpeed             1030 non-null   float64
#  51  HolyResistance          0 non-null      float64
#  52  PVPResilience           3 non-null      float64
#  53  Spirit                  1 non-null      float64
#  54  SpellCritStrikeRating   1 non-null      float64
# dtypes: float64(53), object(2)
# memory usage: 24.6+ MB

# %% [markdown]
# ### Reformat Stats Table
# To bring the table into tidy format all columns except *ID* and *Name* are melted into one stat column and one value column.

# %%
# columns to keep
id_vars = ['ID', 'Name']

# melt the DataFrame
stats = pd.melt(
    stats,
    id_vars=id_vars,
    var_name="Stat",
    value_name="Value"
)

stats = stats.sort_values(by="ID").reset_index(drop=True)

stats
# Out:
#                                            ID                  Name  \
# 0        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 1        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 2        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 3        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 4        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# ...                                       ...                   ...
# 3057512  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057513  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057514  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057515  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057516  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
#
#                           Stat  Value
# 0              RangedDamageMin    NaN
# 1                   SpellPower    NaN
# 2                       Spirit    NaN
# 3               FireResistance    NaN
# 4        RangedHastePercentage    NaN
# ...                        ...    ...
# 3057512                Stamina  517.0
# 3057513            Versatility    NaN
# 3057514       ArcaneResistance    NaN
# 3057515                Mastery  118.0
# 3057516              Avoidance    NaN
#
# [3057517 rows x 4 columns]

# %%
# drop all rows where the value is nan (the item doesn't have this stat)
stats.dropna(how='any', inplace=True)

stats
# Out:
#                                            ID                  Name  \
# 7        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 8        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 34       00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 40       00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 41       00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# ...                                       ...                   ...
# 3057492  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057496  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057506  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057512  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057515  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
#
#                       Stat  Value
# 7                  Stamina   34.0
# 8                  Agility   23.0
# 34               Intellect   23.0
# 40        AgilityIntellect   23.0
# 41                   Armor   37.0
# ...                    ...    ...
# 3057492   CritStrikeRating  132.0
# 3057496           Strength  344.0
# 3057506  StrengthIntellect  344.0
# 3057512            Stamina  517.0
# 3057515            Mastery  118.0
#
# [383103 rows x 4 columns]

# %% [markdown]
# ### Create classes Table

# %%
classes = data[['ID', 'Name', 'Class']]
classes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57689 entries, 0 to 58217
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      57689 non-null  object
#  1   Name    57689 non-null  object
#  2   Class   57689 non-null  object
# dtypes: object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Reformat classes Table
# To bring the table into tidy format, a column for each class is created and filled with one or nan depending on whether the item can be equipped by that class. Afterwards, all class columns are melted into one class column containing only one class name.

# %%
# list of all classes
all_classes = ['Demon hunter', 'Death knight', 'Druid', 'Hunter', 'Mage', 'Monk', 'Paladin', 'Priest', 'Rogue', 'Shaman', 'Warlock', 'Warrior']

# expand 'all' and split multiple classes
def expand_classes(class_name):
    if class_name == 'all':
        return all_classes
    return class_name.split(',')

# create tidy df
classes.loc[:, 'Class'] = classes['Class'].apply(expand_classes)
classes = classes.explode('Class', ignore_index=True)

classes
# Out:
#                                           ID                       Name  \
# 0       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 1       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 2       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 3       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 4       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# ...                                      ...                        ...
# 539779  94e35998-2c99-4ac5-b238-ba631032ceab        Oathsworn Armguards
# 539780  d0bc2a71-74c1-4a3f-b937-095180273b76          Sunsoul Armplates
# 539781  dfb877d7-f8f2-4e66-ae8a-ceae55f979c5     Heart-Lesion Armguards
# 539782  ab5a6976-1666-4128-acf0-a9cb58eac4ac          Sunsoul Armguards
# 539783  d7cf0c96-ec53-4139-ac20-99587efcc330        Springrain Bindings
#
#                Class
# 0       Demon hunter
# 1       Death knight
# 2              Druid
# 3             Hunter
# 4               Mage
# ...              ...
# 539779       Warrior
# 539780       Paladin
# 539781  Death knight
# 539782       Paladin
# 539783         Druid
#
# [539784 rows x 3 columns]

# %%
print(items)
print()
print(classes)
print()
print(stats)
# Out:
#                                          ID                           Name  \
# 0      17469f65-d8f0-4ec6-859b-f9c0cda2a233      Stormpike Soldier's Cloak
# 1      4134640b-4f39-4149-8fa8-126bd3848b1c         Stormpike Sage's Cloak
# 2      948166d8-0fed-41b4-8ed4-06a2b17f68bb  Frostwolf Legionnaire's Cloak
# 3      19efaf00-1328-42ea-ae7d-25822f83fc99                   Banner Cloak
# 4      8d34a535-3873-4975-9581-2bc721e055b4            Demon Scarred Cloak
# ...                                     ...                            ...
# 58213  94e35998-2c99-4ac5-b238-ba631032ceab            Oathsworn Armguards
# 58214  d0bc2a71-74c1-4a3f-b937-095180273b76              Sunsoul Armplates
# 58215  dfb877d7-f8f2-4e66-ae8a-ceae55f979c5         Heart-Lesion Armguards
# 58216  ab5a6976-1666-4128-acf0-a9cb58eac4ac              Sunsoul Armguards
# 58217  d7cf0c96-ec53-4139-ac20-99587efcc330            Springrain Bindings
#
#       Category  Slot   Quality  LvlReq  ArenaRatingReq ProfReq  OnUseEffect  \
# 0         Back    15      Epic      10               0    None        False
# 1         Back    15      Epic      10               0    None        False
# 2         Back    15      Epic      10               0    None        False
# 3         Back    15  Uncommon       0               0    None        False
# 4         Back    15    Common       5               0    None        False
# ...        ...   ...       ...     ...             ...     ...          ...
# 58213    Wrist     9  Uncommon     120               0    None        False
# 58214    Wrist     9  Uncommon     120               0    None        False
# 58215    Wrist     9  Uncommon     120               0    None        False
# 58216    Wrist     9  Uncommon     120               0    None        False
# 58217    Wrist     9  Uncommon     120               0    None        False
#
#        Sockets  SetItem
# 0            0    False
# 1            0    False
# 2            0    False
# 3            0    False
# 4            0    False
# ...        ...      ...
# 58213        0    False
# 58214        0    False
# 58215        0    False
# 58216        0    False
# 58217        0    False
#
# [57689 rows x 11 columns]
#
#                                           ID                       Name  \
# 0       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 1       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 2       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 3       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# 4       17469f65-d8f0-4ec6-859b-f9c0cda2a233  Stormpike Soldier's Cloak
# ...                                      ...                        ...
# 539779  94e35998-2c99-4ac5-b238-ba631032ceab        Oathsworn Armguards
# 539780  d0bc2a71-74c1-4a3f-b937-095180273b76          Sunsoul Armplates
# 539781  dfb877d7-f8f2-4e66-ae8a-ceae55f979c5     Heart-Lesion Armguards
# 539782  ab5a6976-1666-4128-acf0-a9cb58eac4ac          Sunsoul Armguards
# 539783  d7cf0c96-ec53-4139-ac20-99587efcc330        Springrain Bindings
#
#                Class
# 0       Demon hunter
# 1       Death knight
# 2              Druid
# 3             Hunter
# 4               Mage
# ...              ...
# 539779       Warrior
# 539780       Paladin
# 539781  Death knight
# 539782       Paladin
# 539783         Druid
#
# [539784 rows x 3 columns]
#
#                                            ID                  Name  \
# 7        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 8        00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 34       00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 40       00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# 41       00004eaf-a12c-4580-b5eb-be84ae2d9e7b  Cormorant Chain Vest
# ...                                       ...                   ...
# 3057492  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057496  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057506  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057512  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
# 3057515  ffff540a-9b9c-43c0-8ff6-c3039cadef04   Oathsworn Legguards
#
#                       Stat  Value
# 7                  Stamina   34.0
# 8                  Agility   23.0
# 34               Intellect   23.0
# 40        AgilityIntellect   23.0
# 41                   Armor   37.0
# ...                    ...    ...
# 3057492   CritStrikeRating  132.0
# 3057496           Strength  344.0
# 3057506  StrengthIntellect  344.0
# 3057512            Stamina  517.0
# 3057515            Mastery  118.0
#
# [383103 rows x 4 columns]

# %% [markdown]
# ## Create Exploratory Visualizations

# %%
sns.set_theme(style='whitegrid', context='paper')

# %%
# sort classes by counts
sorted_order = classes['Class'].value_counts().index

# create countplot
countplt, ax = plt.subplots(figsize=(10, 5))
ax = sns.countplot(data=classes, y='Class', order=sorted_order)
ax.set_title('Items by Class', size=14)
ax.set_ylabel(None)
ax.set_xlabel('No. of Items', size=10)

sns.despine(left=True)
plt.show()

# %%
# create subset of stats table containing only the main stats: strength, intellect, agility, stamina
main_stats = stats[(stats['Stat'] == 'Strength') | (stats['Stat'] == 'Intellect') | (stats['Stat'] == 'Agility') | (stats['Stat'] == 'Stamina')]
#print(main_stats)

# boxplot for distribution of main stats
boxplt, ax = plt.subplots(figsize=(10, 5))
boxplt.suptitle('Distribution of Main Stats', size=14)
ax = sns.boxplot(data=main_stats, x='Value', y='Stat', orient='h')
plt.xscale('log')
ax.set_xlabel(None)
ax.set_ylabel(None)

sns.despine(left=True, bottom=True)
plt.show()

# %%
# sort classes by counts
sorted_order = ['Poor', 'Common', 'Uncommon', 'Rare', 'Epic', 'Legendary']

# create countplot
countplt, ax = plt.subplots(figsize=(10, 5))
ax = sns.countplot(data=items[(items['Quality'] != 'Artifact') & (items['Quality'] != 'Heirloom')], x='Quality', order=sorted_order)
ax.set_title('Items by Quality', size=14)
ax.set_xlabel(None)
ax.set_ylabel('Number of Items', size=11)

for rect in ax.patches:
    ax.text(x=rect.get_x()+rect.get_width()/2, y=rect.get_height()+200, s=int(rect.get_height()), horizontalalignment='center')

sns.despine(left=True)
plt.show()
